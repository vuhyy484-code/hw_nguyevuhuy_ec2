# %%
#W2A2
ten=input()
print('xin chao', ten)
# Out:
# xin chao huy

# %%
#W2A3
a, b = map(int, input().split())
print(f'{a}+{b}= {a+b}')
print(a-b)
print(a*b)
print(a//b)
print(a%b)
print('%.2f' % (a/b))
# Out:
# 3+5= 8
# -2
# 15
# 0
# 3
# 0.60

# %% [markdown]
# Viết chương trình python để tính điểm trung bình môn học của một học sinh trong lớp. Có tổng cộng
# 6 đầu điểm: a1, b1, c1, a2, b2, a3. Trong đó:
# • Các điểm a1, b1, c1 được nhân hệ số 1,
# • Các điểm a2, b2 được nhân hệ số 2,
# • Điểm a3 được nhân hệ số 3.
# Công thức tính điểm trung bình là: TB=((a1+b1+c1)+(a2+b2)×2+a3×3)/10
# Đầu vào: Trong bài tập này, dữ liệu vào chỉ gồm duy nhất một dòng bao gồm 6 số thể hiện cho 6
# đầu điểm a1, b1, c1, a2, b2, a3 theo đúng thứ tự đó. Trong đó, hai đầu điểm liên tiếp nhau sẽ được
# phân tách nhau bởi duy nhất 1 dấu cách.
# Đầu ra: Đầu ra là giá trị điểm trung bình môn học của 6 môn học, lấy đến 1 chữ số phần thập phân.

# %%
#W2A4
s = input()
a1, b1, c1, a2, b2, a3 = map(int, s.split(' '))
TB=((a1 + b1 + c1) + (a2 + b2)*2 + a3*3)/10
print('%.1f' % TB)
# Out:
# 8.2

# %%
#W2A5
a, b = map(int, input().split())
print(a**b)
# Out:
# 2025

# %%
#W2A6
ky_tu_thuong = input()
ma_unicode = ord(ky_tu_thuong)
ma_hoa = ma_unicode - 32
ky_tu_hoa = chr(ma_hoa)
print(ky_tu_hoa)
# Out:
# G

# %%
#W2A7
A=((13)**20)*3+5
B = 13**2*3 + 5
print(A, B, sep=' = ')
# Out:
# 57014891324642398316408 = 512

# %%
#W2A8
C = float(input())
F=9/5*C + 32
print('%.2f' % F)
# Out:
# 93.56

# %%
#W2A9
x = float(input())
tong_tien = (x + 10) + (x*0.1) + (x*0.3)
print('%.2f' % tong_tien)
# Out:
# 115.29

# %%
#W2A10
a, b, c = map(str, input().split())
print(f'Hi {c}, {b} and {a}.')
# Out:
# Hi long, phong and huy.

# %%
#W2A11
so_gio, so_phut = map(int, input().split())
so_giay = so_gio*3600 + so_phut*60
print(so_giay)
# Out:
# 13500

# %%
#W2A12
n=int(input())
so_mieng_dan = n**2 * 6
print(so_mieng_dan)
# Out:
# 54

# %%
#W2A13
a, b = map(int, input().split())
print((a*b)%10)
# Out:
# 5

# %%
#W2A14
a, b = map(str, input().split())
a, b = b, a
print(f'a={a}, b={b}')
# Out:
# a=23d, b=5

# %%
#W2A15
n = int(input())
so_sao = 6*n*(n - 1) + 1
print(so_sao)
# Out:
# 121

# %%
#W2A16
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
print(" * ")
print(" *** ")
print(" *****")
# Out:
#  *
#  ***
#  *****

# %%
#w2A18
print('### # # ### ###')
print(' #  #  # #   #')
print(' #  #  # #   #')
print(' #  #  # #   #')
print(' #  # #  #   #')
# Out:
# ### # # ### ###
#  #  #  # #   #
#  #  #  # #   #
#  #  #  # #   #
#  #  # #  #   #

# %%
#W2A19
print('Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday')
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W2A21
print("Hello, world\n" * 10, end="")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
